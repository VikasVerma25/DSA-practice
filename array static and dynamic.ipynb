# %%
import array as arr

# %%
a = arr.array('i',[2,4,6])

# %%
a
# Out:
# array('i', [2, 4, 6])

# %%
a[0]
# Out:
# 2

# %%
a.buffer_info()
# Out:
# (2003791057264, 3)

# %%
a[1] = 10

# %%
a.buffer_info()              #same address
# Out:
# (2003791057264, 3)

# %%
a.append(20)

# %%
a.buffer_info()             # address changed
# Out:
# (2003798994320, 4)

# %%
b = arr.array('i', [6])

# %%
import sys

# %%
a.remove(10)

# %%
sys.getsizeof(a)
# Out:
# 92

# %%
a
# Out:
# array('i', [2, 6, 20])

# %%
a.pop()
# Out:
# 20

# %%
sys.getsizeof(a)
# Out:
# 92

# %%
# python list => dynamic array

# %%
db =[1]

# %%
import sys

# %%
sys.getsizeof(db)
# Out:
# 72

# %%
db.append(2)              # reallocated and increased size

# %%
sys.getsizeof(db)
# Out:
# 104

# %%
db.append(4)               # same size O(1) time operation

# %%
sys.getsizeof(db)
# Out:
# 104

# %%
db.append(6)              # same size O(1) time operation

# %%
sys.getsizeof(db)
# Out:
# 104

# %%
db.append(10)               # same size O(1) time operation

# %%
sys.getsizeof(db)
# Out:
# 104

# %%
db.append(22)           # reallocated and increased size

# %%
sys.getsizeof(db)
# Out:
# 136

# %%
import array as arr

# %%
a = arr.array('i',[2,4,6])

# %%
a
# Out:
# array('i', [2, 4, 6])

# %%
a[0]
# Out:
# 2

# %%
a.buffer_info()
# Out:
# (2003791057264, 3)

# %%
a[1] = 10

# %%
a.buffer_info()              #same address
# Out:
# (2003791057264, 3)

# %%
a.append(20)

# %%
a.buffer_info()             # address changed
# Out:
# (2003798994320, 4)

# %%
b = arr.array('i', [6])

# %%
import sys

# %%
a.remove(10)

# %%
sys.getsizeof(a)
# Out:
# 92

# %%
a
# Out:
# array('i', [2, 6, 20])

# %%
a.pop()
# Out:
# 20

# %%
sys.getsizeof(a)
# Out:
# 92

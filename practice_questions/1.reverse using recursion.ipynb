# %%
def rev(s):
    print(s)
    if s==s[0]:                  #base case
        return s
    return rev(s[1:])+s[0]       #Recursion

# %%
rev('vikas')
# Out:
# vikas
# ikas
# kas
# as
# s
# 'sakiv'
